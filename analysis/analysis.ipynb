# %%
import sqlite3
import pandas as pd
from pandas import DataFrame
from functools import reduce
from numpy import array
import numpy as np

# %%
#this connects to sqlite db
conn = sqlite3.connect("/Users/user/Desktop/Research Projects/Coding_and_Analysis/imdb.db")

# %%
#test connection and reformats data as a dataframe with indexed data
df = pd.read_sql_query("SELECT * from encyclopedia \
LEFT OUTER JOIN linktbl on linktbl.uid = encyclopedia.uid", conn)
df = DataFrame(df)
df.columns = df.keys()

# %%
df.nunique()
# Out:
# uid                    1732
# program_title          1672
# program_type             10
# program_genre            30
# network                  57
# first_air_month          13
# first_air_day            31
# first_air_year           13
# last_air_month            3
# last_air_day              3
# last_air_year            37
# program_description    1728
# uid                    1278
# id                     1183
# dtype: int64

# %%
#this query pulls info_type_id 98,3,17,10. These are plot(98), genre(3), keywords(10),trivia(17). 
# NB: I got no values for 10. Also I ultimately dropped the notes column as it looks useless.
#This cell also reformats query into a dataframe and renames second id field as lid
df1 = pd.read_sql_query("SELECT * from movie_info2 \
INNER JOIN linktbl on linktbl.id = movie_info2.movie_id \
WHERE movie_info2.info_type_id = 98 \
OR movie_info2.info_type_id = 3 \
OR movie_info2.info_type_id = 17 \
OR movie_info2.info_type_id = 10", conn)
df1 = DataFrame(df1)
df1.columns = df1.keys()
df1.columns = ['id','movie_id','info_type_id','info','note','uid','lid']

# %%
df1.nunique()
# Out:
# id              4239
# movie_id        1123
# info_type_id       3
# info            2487
# note             106
# uid             1227
# lid             1123
# dtype: int64

# %%
df1['note'].count()
# Out:
# 439

# %%
#this creates a pivot table from info_type_id, creating 3 columns, turning everything else into rows
df_info = df1.pivot_table(values='info', index=['id', 'movie_id', 'uid', 'lid'], columns= 'info_type_id', \
                aggfunc='last')

# %%
df_info.count()
# Out:
# info_type_id
# 3     2112
# 17    2862
# 98     439
# dtype: int64

# %%
#reseting the index
df_info.reset_index(inplace=True)

# %%
df_info.count()
# Out:
# info_type_id
# id          5413
# movie_id    5413
# uid         5413
# lid         5413
# 3           2112
# 17          2862
# 98           439
# dtype: int64

# %%
#this cell drops extraneous columns (id, lid, uid, etc), while grouping 3,98 and 17 by movie_id. 
# This essence we are combining all items associated with like movie_ids into a single cell. 
gb = df_info.groupby(('movie_id'))
result = gb[3].unique()
result1 = gb[98].unique()
result2 = gb[17].unique()

# %%
#in the next three cells, we create a dataframe from the results and print them. movie_id is the index.
result = pd.DataFrame({'movie_id':result.index, '3':result.values})
result.sort_index().head()
# Out:
#                               3  movie_id
# 0                 [None, Drama]     16535
# 1               [None, Western]     18439
# 2  [None, Action, Crime, Drama]     35319
# 3         [None, Comedy, Music]     41569
# 4                      [Comedy]     42033

# %%
result1 = pd.DataFrame({'movie_id':result1.index, '98':result1.values})
result1.sort_index().head()
# Out:
#                                                   98  movie_id
# 0  [None, Private investigator Dennis Chase opera...     16535
# 1                                             [None]     18439
# 2  [None, Stu Bailey and Jeff Spencer were the wi...     35319
# 3                                             [None]     41569
# 4                                             [None]     42033

# %%
result2 = pd.DataFrame({'movie_id':result2.index, '17':result2.values})
result2.sort_index().head()
# Out:
#                                                   17  movie_id
# 0  ["21 Beacon Street" was the address of Dennis ...     16535
# 1  ['Lane Bradford' (qv), who usually played heav...     18439
# 2  [The restaurant, Dino's Lodge, was then owned ...     35319
# 3  [This mish-mash of variety, music and prize gi...     41569
# 4                                             [None]     42033

# %%
#this cell combines the results and merges them by movie_id
dfs = [result, result1, result2]
df_final = reduce(lambda left,right: pd.merge(left,right,on='movie_id'), dfs)

# %%
df_final.head()
# Out:
#                               3  movie_id  \
# 0                 [None, Drama]     16535
# 1               [None, Western]     18439
# 2  [None, Action, Crime, Drama]     35319
# 3         [None, Comedy, Music]     41569
# 4                      [Comedy]     42033
#
#                                                   98  \
# 0  [None, Private investigator Dennis Chase opera...
# 1                                             [None]
# 2  [None, Stu Bailey and Jeff Spencer were the wi...
# 3                                             [None]
# 4                                             [None]
#
#                                                   17
# 0  ["21 Beacon Street" was the address of Dennis ...
# 1  ['Lane Bradford' (qv), who usually played heav...
# 2  [The restaurant, Dino's Lodge, was then owned ...
# 3  [This mish-mash of variety, music and prize gi...
# 4                                             [None]

# %%
#database pull using left outer joins
df2 = pd.read_sql_query("SELECT * from title2 \
LEFT OUTER JOIN movie_companies2 ON title2.id=movie_companies2.movie_id \
LEFT OUTER JOIN company_name2 ON movie_companies2.company_id = company_name2.id \
LEFT OUTER JOIN linktbl on linktbl.id = title2.id \
LEFT OUTER JOIN encyclopedia on encyclopedia.uid = linktbl.uid \
WHERE company_name2.country_code like '[us]' AND title2.kind_id <>7", conn)

# %%
df2.nunique()
# Out:
# id                     2397
# title                  2326
# imdb_index                3
# kind_id                   2
# production_year          20
# imdb_id                   0
# phonetic_code          1775
# episode_of_id             0
# season_nr                 0
# episode_nr                0
# series_years            238
# md5sum                 2397
# id                     5744
# movie_id               2397
# company_id              863
# company_type_id           2
# note                   1067
# id                      863
# name                    863
# country_code              1
# imdb_id                   0
# name_pcode_nf           708
# name_pcode_sf           702
# md5sum                  863
# uid                    1264
# id                     1165
# uid                    1264
# program_title          1213
# program_type              7
# program_genre            27
# network                  49
# first_air_month          12
# first_air_day            23
# first_air_year           13
# last_air_month            2
# last_air_day              2
# last_air_year            37
# program_description    1263
# dtype: int64

# %%
#this column turns df2 into a dataframe, indexes it, drops unnecessary columns and renames it as df3
df2 = DataFrame(df2)
df2.columns = df2.keys()
df3 = df2.drop(columns=['imdb_id', 'imdb_index', 'name', 'phonetic_code', 'episode_of_id', 'season_nr', 'episode_nr', 'md5sum', 'id','company_id', \
         'company_type_id', 'note', 'id', 'country_code', 'imdb_id', 'name_pcode_nf', 'name_pcode_sf', 'md5sum' \
         'id', 'uid', 'first_air_month', 'first_air_day', 'last_air_month', 'last_air_day'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6699 entries, 0 to 6698
# Data columns (total 12 columns):
# title                  6699 non-null object
# kind_id                6699 non-null int64
# production_year        6699 non-null int64
# series_years           5693 non-null object
# movie_id               6699 non-null int64
# program_title          4447 non-null object
# program_type           4447 non-null object
# program_genre          4447 non-null object
# network                4447 non-null object
# first_air_year         4447 non-null float64
# last_air_year          4447 non-null object
# program_description    4447 non-null object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 628.1+ KB

# %%
df3.nunique()
# Out:
# title                  2326
# kind_id                   2
# production_year          20
# series_years            238
# movie_id               2397
# program_title          1213
# program_type              7
# program_genre            27
# network                  49
# first_air_year           13
# last_air_year            37
# program_description    1263
# dtype: int64

# %%
#this cell performs a left merge between df3 and df_final. It merges on movie_id
frames = pd.merge(df3, df_final, how='left', on=['movie_id', 'movie_id'])

# %%
frames
# Out:
#                            title  kind_id  production_year series_years  \
# 0                13 Demon Street        2             1959    1959-1960
# 1                13 Demon Street        2             1959    1959-1960
# 2                      13th Hour        2             1958    1958-1959
# 3                      13th Hour        2             1958    1958-1959
# 4              1947 World Series        2             1947    1947-????
# 5              1947 World Series        2             1947    1947-????
# 6              1948 World Series        2             1948    1948-????
# 7              1948 World Series        2             1948    1948-????
# 8              1948 World Series        2             1948    1948-????
# 9              1949 World Series        2             1949    1949-????
# 10             1950 World Series        2             1950    1950-????
# 11             1950 World Series        2             1950    1950-????
# 12             1951 World Series        2             1951    1951-????
# 13             1951 World Series        2             1951    1951-????
# 14             1952 World Series        2             1952    1952-????
# 15             1953 World Series        2             1953    1953-????
# 16             1954 World Series        2             1954    1954-????
# 17             1955 World Series        2             1955    1955-????
# 18             1956 World Series        2             1956    1956-????
# 19             1957 World Series        2             1957    1957-????
# 20             1957 World Series        2             1957    1957-????
# 21             1958 World Series        2             1958    1958-????
# 22             1958 World Series        2             1958    1958-????
# 23             1959 World Series        2             1959    1959-????
# 24                  20 Questions        2             1949    1949-????
# 25                  20 Questions        2             1949    1949-????
# 26                  20 Questions        2             1949    1949-????
# 27                  20 Questions        2             1949    1949-????
# 28                  20 Questions        2             1949    1949-????
# 29                  20 Questions        2             1949    1949-????
# ...                          ...      ...              ...          ...
# 6669             Uninvited Guest        3             1944         None
# 6670             Uninvited Guest        3             1944         None
# 6671                    Untitled        3             1945         None
# 6672                    Untitled        3             1945         None
# 6673                     Victory        3             1945         None
# 6674                     Victory        3             1945         None
# 6675                Walk with Me        3             1946         None
# 6676                Walk with Me        3             1946         None
# 6677             Well, Goodnight        3             1946         None
# 6678             Well, Goodnight        3             1946         None
# 6679        Where We Stand: 1959        3             1959         None
# 6680        Where We Stand: 1959        3             1959         None
# 6681                   Winterset        3             1945         None
# 6682                   Winterset        3             1945         None
# 6683                   Winterset        3             1959         None
# 6684          Woman with a Sword        3             1952         None
# 6685          Woman with a Sword        3             1952         None
# 6686              Wonderful Town        3             1958         None
# 6687              Wonderful Town        3             1958         None
# 6688              Wonderful Town        3             1958         None
# 6689           World by the Tail        3             1953         None
# 6690             World in Crisis        3             1956         None
# 6691             World in Crisis        3             1956         None
# 6692              World in White        3             1957         None
# 6693              World in White        3             1957         None
# 6694       Write Me a Love Scene        3             1946         None
# 6695       Write Me a Love Scene        3             1946         None
# 6696  You Can't Take It with You        3             1945         None
# 6697  You Can't Take It with You        3             1945         None
# 6698          Young Couples Only        3             1955         None
#
#       movie_id      program_title program_type program_genre network  \
# 0         8305               None         None          None    None
# 1         8305               None         None          None    None
# 2         9296               None         None          None    None
# 3         9296               None         None          None    None
# 4        10916               None         None          None    None
# 5        10916               None         None          None    None
# 6        10924               None         None          None    None
# 7        10924               None         None          None    None
# 8        10924               None         None          None    None
# 9        10931               None         None          None    None
# 10       10938               None         None          None    None
# 11       10938               None         None          None    None
# 12       10943               None         None          None    None
# 13       10943               None         None          None    None
# 14       10950               None         None          None    None
# 15       10958               None         None          None    None
# 16       10965               None         None          None    None
# 17       10970               None         None          None    None
# 18       10978               None         None          None    None
# 19       10986               None         None          None    None
# 20       10986               None         None          None    None
# 21       10994               None         None          None    None
# 22       10994               None         None          None    None
# 23       11002               None         None          None    None
# 24       14124               None         None          None    None
# 25       14124               None         None          None    None
# 26       14124               None         None          None    None
# 27       14124               None         None          None    None
# 28       14124               None         None          None    None
# 29       14124               None         None          None    None
# ...        ...                ...          ...           ...     ...
# 6669   4507203               None         None          None    None
# 6670   4507203               None         None          None    None
# 6671   4509959               None         None          None    None
# 6672   4509959               None         None          None    None
# 6673   4525780   Victory at Sea.        Series   Documentary     NBC
# 6674   4525780   Victory at Sea.        Series   Documentary     NBC
# 6675   4538663               None         None          None    None
# 6676   4538663               None         None          None    None
# 6677   4548355               None         None          None    None
# 6678   4548355               None         None          None    None
# 6679   4556350               None         None          None    None
# 6680   4556350               None         None          None    None
# 6681   4565618               None         None          None    None
# 6682   4565618               None         None          None    None
# 6683   4565619               None         None          None    None
# 6684   4568792               None         None          None    None
# 6685   4568792               None         None          None    None
# 6686   4569747               None         None          None    None
# 6687   4569747               None         None          None    None
# 6688   4569747               None         None          None    None
# 6689   4571037               None         None          None    None
# 6690   4571165               None         None          None    None
# 6691   4571165               None         None          None    None
# 6692   4571168               None         None          None    None
# 6693   4571168               None         None          None    None
# 6694   4572766               None         None          None    None
# 6695   4572766               None         None          None    None
# 6696   4582865               None         None          None    None
# 6697   4582865               None         None          None    None
# 6698   4584399               None         None          None    None
#
#       first_air_year last_air_year  \
# 0                NaN          None
# 1                NaN          None
# 2                NaN          None
# 3                NaN          None
# 4                NaN          None
# 5                NaN          None
# 6                NaN          None
# 7                NaN          None
# 8                NaN          None
# 9                NaN          None
# 10               NaN          None
# 11               NaN          None
# 12               NaN          None
# 13               NaN          None
# 14               NaN          None
# 15               NaN          None
# 16               NaN          None
# 17               NaN          None
# 18               NaN          None
# 19               NaN          None
# 20               NaN          None
# 21               NaN          None
# 22               NaN          None
# 23               NaN          None
# 24               NaN          None
# 25               NaN          None
# 26               NaN          None
# 27               NaN          None
# 28               NaN          None
# 29               NaN          None
# ...              ...           ...
# 6669             NaN          None
# 6670             NaN          None
# 6671             NaN          None
# 6672             NaN          None
# 6673          1952.0          1953
# 6674          1952.0          1953
# 6675             NaN          None
# 6676             NaN          None
# 6677             NaN          None
# 6678             NaN          None
# 6679             NaN          None
# 6680             NaN          None
# 6681             NaN          None
# 6682             NaN          None
# 6683             NaN          None
# 6684             NaN          None
# 6685             NaN          None
# 6686             NaN          None
# 6687             NaN          None
# 6688             NaN          None
# 6689             NaN          None
# 6690             NaN          None
# 6691             NaN          None
# 6692             NaN          None
# 6693             NaN          None
# 6694             NaN          None
# 6695             NaN          None
# 6696             NaN          None
# 6697             NaN          None
# 6698             NaN          None
#
#                                     program_description        3      98  \
# 0                                                  None      NaN     NaN
# 1                                                  None      NaN     NaN
# 2                                                  None      NaN     NaN
# 3                                                  None      NaN     NaN
# 4                                                  None      NaN     NaN
# 5                                                  None      NaN     NaN
# 6                                                  None      NaN     NaN
# 7                                                  None      NaN     NaN
# 8                                                  None      NaN     NaN
# 9                                                  None      NaN     NaN
# 10                                                 None      NaN     NaN
# 11                                                 None      NaN     NaN
# 12                                                 None      NaN     NaN
# 13                                                 None      NaN     NaN
# 14                                                 None      NaN     NaN
# 15                                                 None      NaN     NaN
# 16                                                 None      NaN     NaN
# 17                                                 None      NaN     NaN
# 18                                                 None      NaN     NaN
# 19                                                 None      NaN     NaN
# 20                                                 None      NaN     NaN
# 21                                                 None      NaN     NaN
# 22                                                 None      NaN     NaN
# 23                                                 None      NaN     NaN
# 24                                                 None      NaN     NaN
# 25                                                 None      NaN     NaN
# 26                                                 None      NaN     NaN
# 27                                                 None      NaN     NaN
# 28                                                 None      NaN     NaN
# 29                                                 None      NaN     NaN
# ...                                                 ...      ...     ...
# 6669                                               None      NaN     NaN
# 6670                                               None      NaN     NaN
# 6671                                               None      NaN     NaN
# 6672                                               None      NaN     NaN
# 6673   Films that detail the United States Naval ope...  [Drama]  [None]
# 6674   Films that detail the United States Naval ope...  [Drama]  [None]
# 6675                                               None      NaN     NaN
# 6676                                               None      NaN     NaN
# 6677                                               None      NaN     NaN
# 6678                                               None      NaN     NaN
# 6679                                               None      NaN     NaN
# 6680                                               None      NaN     NaN
# 6681                                               None      NaN     NaN
# 6682                                               None      NaN     NaN
# 6683                                               None      NaN     NaN
# 6684                                               None      NaN     NaN
# 6685                                               None      NaN     NaN
# 6686                                               None      NaN     NaN
# 6687                                               None      NaN     NaN
# 6688                                               None      NaN     NaN
# 6689                                               None      NaN     NaN
# 6690                                               None      NaN     NaN
# 6691                                               None      NaN     NaN
# 6692                                               None      NaN     NaN
# 6693                                               None      NaN     NaN
# 6694                                               None      NaN     NaN
# 6695                                               None      NaN     NaN
# 6696                                               None      NaN     NaN
# 6697                                               None      NaN     NaN
# 6698                                               None      NaN     NaN
#
#           17
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# ...      ...
# 6669     NaN
# 6670     NaN
# 6671     NaN
# 6672     NaN
# 6673  [None]
# 6674  [None]
# 6675     NaN
# 6676     NaN
# 6677     NaN
# 6678     NaN
# 6679     NaN
# 6680     NaN
# 6681     NaN
# 6682     NaN
# 6683     NaN
# 6684     NaN
# 6685     NaN
# 6686     NaN
# 6687     NaN
# 6688     NaN
# 6689     NaN
# 6690     NaN
# 6691     NaN
# 6692     NaN
# 6693     NaN
# 6694     NaN
# 6695     NaN
# 6696     NaN
# 6697     NaN
# 6698     NaN
#
# [6699 rows x 15 columns]

# %%
#this cell checks the columns for stray white space
frames.columns
# Out:
# Index(['title', 'kind_id', 'production_year', 'series_years', 'movie_id',
#        'program_title', 'program_type', 'program_genre', 'network',
#        'first_air_year', 'last_air_year', 'program_description', '3', '98',
#        '17'],
#       dtype='object')

# %%
#these three cells rename columns
frames = frames.rename(columns={'3': 'genre(3)'})

# %%
frames = frames.rename(columns={'98': 'plot(98)'})

# %%
frames = frames.rename(columns={'17': 'trivia(17)'})

# %%
frames.head()
# Out:
#                title  kind_id  production_year series_years  movie_id  \
# 0    13 Demon Street        2             1959    1959-1960      8305
# 1    13 Demon Street        2             1959    1959-1960      8305
# 2          13th Hour        2             1958    1958-1959      9296
# 3          13th Hour        2             1958    1958-1959      9296
# 4  1947 World Series        2             1947    1947-????     10916
#
#   program_title program_type program_genre network  first_air_year  \
# 0          None         None          None    None             NaN
# 1          None         None          None    None             NaN
# 2          None         None          None    None             NaN
# 3          None         None          None    None             NaN
# 4          None         None          None    None             NaN
#
#   last_air_year program_description genre(3) plot(98) trivia(17)
# 0          None                None      NaN      NaN        NaN
# 1          None                None      NaN      NaN        NaN
# 2          None                None      NaN      NaN        NaN
# 3          None                None      NaN      NaN        NaN
# 4          None                None      NaN      NaN        NaN

# %%
#This generates the real title list by checking if the program_title string has a length >= 1, if so it populates the column
frames['realtitle'] = np.where(frames['program_title'].str.len()>=1, frames['program_title'], frames['title'])

# %%
frames.head()
# Out:
#                title  kind_id  production_year series_years  movie_id  \
# 0    13 Demon Street        2             1959    1959-1960      8305
# 1    13 Demon Street        2             1959    1959-1960      8305
# 2          13th Hour        2             1958    1958-1959      9296
# 3          13th Hour        2             1958    1958-1959      9296
# 4  1947 World Series        2             1947    1947-????     10916
#
#   program_title program_type program_genre network  first_air_year  \
# 0          None         None          None    None             NaN
# 1          None         None          None    None             NaN
# 2          None         None          None    None             NaN
# 3          None         None          None    None             NaN
# 4          None         None          None    None             NaN
#
#   last_air_year program_description genre(3) plot(98) trivia(17)  \
# 0          None                None      NaN      NaN        NaN
# 1          None                None      NaN      NaN        NaN
# 2          None                None      NaN      NaN        NaN
# 3          None                None      NaN      NaN        NaN
# 4          None                None      NaN      NaN        NaN
#
#            realtitle
# 0    13 Demon Street
# 1    13 Demon Street
# 2          13th Hour
# 3          13th Hour
# 4  1947 World Series

# %%
#reorder columns by typing in the column names. Note the double brackets.
frames = frames[['realtitle','program_type','program_genre','network','program_description','first_air_year','last_air_year','genre(3)','plot(98)','trivia(17)','program_title','movie_id','kind_id','title']]

# %%
frames.head(10)
# Out:
#            realtitle program_type program_genre network program_description  \
# 0    13 Demon Street         None          None    None                None
# 1    13 Demon Street         None          None    None                None
# 2          13th Hour         None          None    None                None
# 3          13th Hour         None          None    None                None
# 4  1947 World Series         None          None    None                None
# 5  1947 World Series         None          None    None                None
# 6  1948 World Series         None          None    None                None
# 7  1948 World Series         None          None    None                None
# 8  1948 World Series         None          None    None                None
# 9  1949 World Series         None          None    None                None
#
#    first_air_year last_air_year genre(3) plot(98) trivia(17) program_title  \
# 0             NaN          None      NaN      NaN        NaN          None
# 1             NaN          None      NaN      NaN        NaN          None
# 2             NaN          None      NaN      NaN        NaN          None
# 3             NaN          None      NaN      NaN        NaN          None
# 4             NaN          None      NaN      NaN        NaN          None
# 5             NaN          None      NaN      NaN        NaN          None
# 6             NaN          None      NaN      NaN        NaN          None
# 7             NaN          None      NaN      NaN        NaN          None
# 8             NaN          None      NaN      NaN        NaN          None
# 9             NaN          None      NaN      NaN        NaN          None
#
#    movie_id  kind_id              title
# 0      8305        2    13 Demon Street
# 1      8305        2    13 Demon Street
# 2      9296        2          13th Hour
# 3      9296        2          13th Hour
# 4     10916        2  1947 World Series
# 5     10916        2  1947 World Series
# 6     10924        2  1948 World Series
# 7     10924        2  1948 World Series
# 8     10924        2  1948 World Series
# 9     10931        2  1949 World Series

# %%
frames.columns
# Out:
# Index(['realtitle', 'program_type', 'program_genre', 'network',
#        'program_description', 'first_air_year', 'last_air_year', 'genre(3)',
#        'plot(98)', 'trivia(17)', 'program_title', 'movie_id', 'kind_id',
#        'title'],
#       dtype='object')

# %%
frames = frames.rename(columns=lambda x: x.strip())

# %%
frames.to_csv('frames.csv', encoding='utf-8')
